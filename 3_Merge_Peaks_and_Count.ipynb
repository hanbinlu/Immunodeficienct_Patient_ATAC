# %%
# %load_ext lab_black

# %%
import subprocess, logging, sys, glob

FORMAT = "%(asctime)s: %(message)s"
logging.basicConfig(stream=sys.stdout, level=logging.INFO, format=FORMAT)

sys.path.append("/home/murrelab/MiD_HiChIP_Project/data_to_publish/hic_analysis_utils/")

import region_coverage
import pyranges as pr
import pandas as pd
import numpy as np
# Out:
# 2022-04-23 23:50:10,665: Note: NumExpr detected 40 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2022-04-23 23:50:10,667: NumExpr defaulting to 8 threads.

# %%
all_bam = {
    bam_path.split("/")[1].split(".trim")[0]: bam_path
    for bam_path in glob.glob("bam/*bam")
}

# %% [markdown]
# Merge all simulated B ATAC peaks

# %%
merged = None
for sample_label in all_bam.keys():
    macs2_peak_file = f"macs2_results/{sample_label}/{sample_label}_peaks.narrowPeak"
    if "_M" in sample_label:
        print("Not include", sample_label)
        continue

    count = sum(1 for line in open(macs2_peak_file))
    if count < 10_000:
        print("Not include", sample_label, " because of low signal")
        continue

    peaks = (
        pd.read_csv(
            macs2_peak_file,
            header=None,
            sep="\t",
        )
        .iloc[:, [0, 1, 2]]
        .rename(columns={0: "Chromosome", 1: "Start", 2: "End"})
    )
    if merged is None:
        merged = peaks
    else:
        merged = pr.PyRanges(pd.concat([merged, peaks], ignore_index=True)).cluster()
        merged = merged.df.groupby("Cluster").apply(
            lambda df: pd.Series(
                {
                    "Chromosome": df.Chromosome.iloc[0],
                    "Start": df.Start.min(),
                    "End": df.End.max(),
                }
            )
        )
# Out:
# Not include ATAC308_BG_FR105.1_CTLA4_sB  because of low signal
# Not include ATAC033_CB_FR008.1_CTLA4_sB  because of low signal
# Not include ATAC250_CB_FR083.1_CVID_M
# Not include ATAC024_CB_FR005.1_NFKB1_sB  because of low signal
# Not include ATAC247_CB_FR082.1_TACI_M

# %% [markdown]
# One-hot encoding for peak origins

# %%
for sample_label in all_bam.keys():
    macs2_peak_file = f"macs2_results/{sample_label}/{sample_label}_peaks.narrowPeak"
    if "_M" in sample_label:
        continue
    count = sum(1 for line in open(macs2_peak_file))
    if count < 10_000:
        continue

    merged = pr.PyRanges(merged)
    peaks = pr.PyRanges(
        pd.read_csv(
            macs2_peak_file,
            header=None,
            sep="\t",
        )
        .iloc[:, [0, 1, 2]]
        .rename(columns={0: "Chromosome", 1: "Start", 2: "End"})
    )
    merged = merged.coverage(peaks, overlap_col=sample_label, fraction_col="F").df.drop(
        columns="F"
    )
    merged[sample_label] = merged[sample_label].astype(bool)

# %%
merged_raw = merged.copy()

# %% [markdown]
# Count coverage at peaks

# %%
merged = pr.PyRanges(merged_raw.copy())
for sample_label, bam in all_bam.items():
    macs2_peak_file = f"macs2_results/{sample_label}/{sample_label}_peaks.narrowPeak"
    if "_M" in sample_label:
        continue
    count = sum(1 for line in open(macs2_peak_file))
    if count < 10_000:
        continue

    # transform bam to bed format
    with open("temp.bed", "w") as o:
        tobed = subprocess.Popen(
            f"bedtools bamtobed -i {bam}",
            shell=True,
            stdout=subprocess.PIPE,
        )
        subprocess.run(
            "cut -f1-3",
            shell=True,
            stdin=tobed.stdout,
            stdout=o,
        )
        tobed.wait()
    scaled_counts = region_coverage.region_coverage(
        merged, "temp.bed", fill_zeros=False
    )
    merged = merged.insert(pd.Series(data=scaled_counts, name=f"Count_{sample_label}"))

# %%
merged.to_csv("merge_peaks.RPM_count.txt", sep="\t")

# %% [markdown]
# Raw counts

# %%
merged = pr.PyRanges(merged_raw.copy())
for sample_label, bam in all_bam.items():
    macs2_peak_file = f"macs2_results/{sample_label}/{sample_label}_peaks.narrowPeak"
    if "_M" in sample_label:
        continue
    count = sum(1 for line in open(macs2_peak_file))
    if count < 10_000:
        continue

    # transform bam to bed format
    with open("temp.bed", "w") as o:
        tobed = subprocess.Popen(
            f"bedtools bamtobed -i {bam}",
            shell=True,
            stdout=subprocess.PIPE,
        )
        subprocess.run(
            "cut -f1-3",
            shell=True,
            stdin=tobed.stdout,
            stdout=o,
        )
        tobed.wait()
    scaled_counts = region_coverage.region_coverage(
        merged, "temp.bed", fill_zeros=False, scale_to=0
    )
    merged = merged.insert(pd.Series(data=scaled_counts, name=f"Count_{sample_label}"))

# %%
for column in merged.columns:
    if "Count" in column:
        merged = merged.assign(column, lambda df: df[column].astype(int))

# %%
merged.to_csv("merge_peaks.raw_count.txt", sep="\t")

# %%
import pandas as pd
import numpy as np

# %%
count_tbl = pd.read_csv("merge_peaks.raw_count.txt", sep="\t")

# %%
nt_samples = count_tbl.columns.str.match(r"^ATAC.*ND")
nfkb1_samples = count_tbl.columns.str.match(r"^ATAC.*NFKB1")

# %%
count_tbl.loc[
    count_tbl.loc[:, np.logical_or(nt_samples, nfkb1_samples)].apply(np.any, axis=1), :
]
# Out:
#        Chromosome     Start       End  ATAC188_CB_FR062.1_ND_sB  \
# 0            chr1     10043     10267                      True
# 1            chr1    180704    180974                      True
# 2            chr1    181330    181577                      True
# 6            chr1    629820    630076                      True
# 7            chr1    630217    630417                     False
# ...           ...       ...       ...                       ...
# 147445       chrY  56734665  56734914                      True
# 147446       chrY  56742630  56742792                      True
# 147447       chrY  56763398  56763651                      True
# 147448       chrY  56837247  56837352                     False
# 147449       chrY  56870861  56871030                     False
#
#         ATAC088_CB_FR028.1_CVID_sB  ATAC111_CB_FR036.1_NFKB1_sB  \
# 0                             True                         True
# 1                             True                        False
# 2                             True                         True
# 6                             True                         True
# 7                            False                        False
# ...                            ...                          ...
# 147445                       False                        False
# 147446                       False                        False
# 147447                       False                        False
# 147448                       False                        False
# 147449                       False                        False
#
#         ATAC212_CB_FR071.1_CVID_sB  ATAC179_CB_FR059.1_TACI_sB  \
# 0                            False                        True
# 1                            False                       False
# 2                             True                        True
# 6                             True                        True
# 7                            False                       False
# ...                            ...                         ...
# 147445                       False                       False
# 147446                       False                       False
# 147447                       False                       False
# 147448                       False                       False
# 147449                       False                       False
#
#         ATAC270_CB_FR090.1_CVID_sB  ATAC128_CB_FR042.1_CVID_sB  ...  \
# 0                            False                       False  ...
# 1                             True                       False  ...
# 2                            False                       False  ...
# 6                             True                        True  ...
# 7                            False                       False  ...
# ...                            ...                         ...  ...
# 147445                        True                       False  ...
# 147446                        True                       False  ...
# 147447                        True                       False  ...
# 147448                       False                       False  ...
# 147449                       False                       False  ...
#
#         Count_ATAC027_CB_FR006.1_TACI_sB  Count_ATAC191_CB_FR063.1_ND_sB  \
# 0                                     16                              15
# 1                                     12                              11
# 2                                      3                              15
# 6                                     57                              56
# 7                                      4                               1
# ...                                  ...                             ...
# 147445                                24                               0
# 147446                                11                               0
# 147447                                31                               1
# 147448                                 9                               4
# 147449                                 9                               9
#
#         Count_ATAC085_CB_FR027.1_CTLA4_sB  Count_ATAC273_CB_FR091.1_HIES_sB  \
# 0                                      12                                 9
# 1                                      21                                10
# 2                                       1                                 3
# 6                                      57                                55
# 7                                       0                                 3
# ...                                   ...                               ...
# 147445                                  0                                20
# 147446                                  0                                 5
# 147447                                  0                                19
# 147448                                  6                                 3
# 147449                                  3                                 7
#
#         Count_ATAC105_CB_FR034.1_NFKB2_sB  Count_ATAC298_BG_FR101.1_NFKB1_sB  \
# 0                                       5                                 12
# 1                                       5                                 13
# 2                                       9                                  2
# 6                                      54                                 62
# 7                                       0                                  3
# ...                                   ...                                ...
# 147445                                  0                                  0
# 147446                                  0                                  0
# 147447                                  0                                  0
# 147448                                  8                                  7
# 147449                                  5                                  3
#
#         Count_ATAC242_CB_FR080.1_CVID_sB  Count_ATAC185_CB_FR061.1_ND_sB  \
# 0                                     13                              11
# 1                                     15                              14
# 2                                      9                              12
# 6                                     56                              51
# 7                                      0                               2
# ...                                  ...                             ...
# 147445                                30                               0
# 147446                                11                               0
# 147447                                24                               0
# 147448                                10                               3
# 147449                                10                               9
#
#         Count_ATAC224_CB_FR075.1_ND_sB  Count_ATAC218_CB_FR073.1_CVID_sB
# 0                                   13                                11
# 1                                    8                                10
# 2                                   14                                 7
# 6                                   55                                55
# 7                                    2                                 4
# ...                                ...                               ...
# 147445                               0                                 0
# 147446                               0                                 0
# 147447                               0                                 0
# 147448                               3                                 5
# 147449                               7                                 2
#
# [88870 rows x 141 columns]
